# %% [markdown]
# ## Classification - Binary (label)
#
# Workflow:
# 1. Load reduced datasets and target
# 2. Define models and hyperparameter grids (Decision Tree, Logistic Regression)
# 3. Run GridSearchCV for each model on KBest
# 4. Display the collected results
# 5. Show confusion matrix and classification report for the best combination

# %%
# 1. Load reduced datasets (KBest and PCA) and target

import pandas as pd

X_train_kbest = pd.read_parquet("../data/reduced/X_train_kbest_label.parquet")
X_test_kbest = pd.read_parquet("../data/reduced/X_test_kbest_label.parquet")
X_train_multi = pd.read_parquet("../data/reduced/X_train_kbest_cat.parquet")
X_test_multi = pd.read_parquet("../data/reduced/X_test_kbest_cat.parquet")
y_train_multi = pd.read_parquet("../data/processed/y_cat_train.parquet")['attack_cat']
y_test_multi = pd.read_parquet("../data/processed/y_cat_test.parquet")['attack_cat']
X_train_pca = pd.read_parquet("../data/reduced/X_train_pca.parquet")
X_test_pca = pd.read_parquet("../data/reduced/X_test_pca.parquet")

y_train = pd.read_parquet("../data/processed/y_label_train.parquet")['label']
y_test = pd.read_parquet("../data/processed/y_label_test.parquet")['label']

print(f"KBest: {X_train_kbest.shape}, PCA: {X_train_pca.shape}")
# Out:
# KBest: (64870, 50), PCA: (64870, 137)

# %%
# Fit an unconstrained tree to find a sensible upper bound for max_depth

from sklearn.tree import DecisionTreeClassifier

random_state = 42

full_tree_kbest = DecisionTreeClassifier(random_state=random_state).fit(X_train_kbest, y_train)
full_tree_pca = DecisionTreeClassifier(random_state=random_state).fit(X_train_pca, y_train)

fitted_max_depth = max(full_tree_kbest.get_depth(), full_tree_pca.get_depth())
print(f"Max unconstrained depth (KBest: {full_tree_kbest.get_depth()}, PCA: {full_tree_pca.get_depth()}): {fitted_max_depth}")
# Out:
# Max unconstrained depth (KBest: 51, PCA: 44): 51

# %%
# 2. Define models and hyperparameter grids

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

random_state = 42

models = {
    'dt': {
        'name': 'Decision Tree',
        'estimator': DecisionTreeClassifier(random_state = random_state),
        'param': [{
            'max_depth': list(range(1, min(fitted_max_depth, 20) + 1)),
            'criterion': ['entropy', 'gini'],
            'class_weight': [None, 'balanced']
        }]
    },
    'rf': {
        'name': 'Random Forest',
        'estimator': RandomForestClassifier(random_state = random_state),
        'param': [{
            'n_estimators': list(range(10, 60, 10)),
            'max_depth': [5, 10, 15, None],
            'class_weight': [None, 'balanced']
        }]
    }
}

representations = {
    'kbest': {'X_train': X_train_kbest, 'X_test': X_test_kbest},
    #'pca':   {'X_train': X_train_pca,   'X_test': X_test_pca}
}

# %%
# 3. Run GridSearchCV for each model on each representation

from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report

scoring = 'f1'
cv = StratifiedKFold(n_splits=3, random_state=random_state, shuffle=True)

clfs = {}
results = pd.DataFrame(columns=['representation', 'model_lbl', 'best_params', 'accuracy', 'precision', 'recall', 'f1'])

for rep_name, rep_data in representations.items():
    Xtr, Xte = rep_data['X_train'], rep_data['X_test']

    for model_lbl, model_info in models.items():
        print(f"Tuning {model_info['name']} on {rep_name}...")

        clf = GridSearchCV(
            model_info['estimator'],
            model_info['param'],
            cv=cv,
            scoring=scoring,
            n_jobs=-1
        )
        clf.fit(Xtr, y_train)

        y_pred = clf.predict(Xte)
        cr = classification_report(y_test, y_pred, output_dict=True, zero_division=0)

        clfs[f"{model_lbl}_kbest"] = clf

        results.loc[len(results)] = [
            rep_name,
            model_lbl,
            clf.best_params_,
            cr['accuracy'],
            cr['weighted avg']['precision'],
            cr['weighted avg']['recall'],
            cr['weighted avg']['f1-score']
        ]

print("\nDone.")
# Out:
# Tuning Decision Tree on kbest...
# Tuning Random Forest on kbest...
#
# Done.

# %%
#Display the collected results

results = results.sort_values(by='f1', ascending=False).reset_index(drop=True)

display(
    results.style.format(precision=3)
           .set_caption('Binary classification results (label)')
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f0639">
#   <caption>Binary classification results (label)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0639_level0_col0" class="col_heading level0 col0" >representation</th>
#       <th id="T_f0639_level0_col1" class="col_heading level0 col1" >model_lbl</th>
#       <th id="T_f0639_level0_col2" class="col_heading level0 col2" >best_params</th>
#       <th id="T_f0639_level0_col3" class="col_heading level0 col3" >accuracy</th>
#       <th id="T_f0639_level0_col4" class="col_heading level0 col4" >precision</th>
#       <th id="T_f0639_level0_col5" class="col_heading level0 col5" >recall</th>
#       <th id="T_f0639_level0_col6" class="col_heading level0 col6" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0639_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0639_row0_col0" class="data row0 col0" >kbest</td>
# ...

# %%
# 5. Show confusion matrix and classification report for the best combination

import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

best_key = f"{results.loc[0, 'model_lbl']}_kbest"
best_label = models[results.loc[0, 'model_lbl']]['name']
best_clf = clfs[best_key]

y_pred_best = best_clf.predict(X_test_kbest)

print(f"Best combination: {best_label}")
print(f"Best params: {results.loc[0, 'best_params']}")
print()
print(classification_report(y_test, y_pred_best, zero_division=0))

disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred_best, normalize='true')
disp.ax_.set_title(f"Confusion Matrix — {best_label}")
plt.show()
# Out:
# Best combination: Random Forest
# Best params: {'class_weight': None, 'max_depth': 15, 'n_estimators': 50}
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.92     16135
#            1       0.88      0.96      0.92     15817
#
#     accuracy                           0.92     31952
#    macro avg       0.92      0.92      0.92     31952
# weighted avg       0.92      0.92      0.92     31952
